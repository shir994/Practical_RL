# %%
# %env CUDA_VISIBLE_DEVICES=2
# %env LIBRARY_PATH=/usr/local/cuda/lib64
import sys
import os
sys.path.append(os.path.expanduser("~/.local/lib/python3.6/site-packages/"))
# Out:
# env: CUDA_VISIBLE_DEVICES=2
# env: LIBRARY_PATH=/usr/local/cuda/lib64

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Week 8: Reinforcement Learning for seq2seq
#
# This time we'll solve a problem of transribing hebrew words in english, also known as g2p (grapheme2phoneme)
#
#  * word (sequence of letters in source language) -> translation (sequence of letters in target language)
#
# Unlike most deep learning practicioners do, we won't only train it to maximize likelihood of correct translation, but also employ reinforcement learning to actually teach it to translate with as few errors as possible.
#
#
# ### About the task
#
# One notable property of Hebrew is that it's consonant language. That is, there are no wovels in the written language. One could represent wovels with diacritics above consonants, but you don't expect people to do that in everyay life.
#
# Therefore, some hebrew characters will correspond to several english letters and others - to none, so we should use encoder-decoder architecture to figure that out.
#
# ![img](https://esciencegroup.files.wordpress.com/2016/03/seq2seq.jpg)
# _(img: esciencegroup.files.wordpress.com)_
#
# Encoder-decoder architectures are about converting anything to anything, including
#  * Machine translation and spoken dialogue systems
#  * [Image captioning](http://mscoco.org/dataset/#captions-challenge2015) and [image2latex](https://openai.com/requests-for-research/#im2latex) (convolutional encoder, recurrent decoder)
#  * Generating [images by captions](https://arxiv.org/abs/1511.02793) (recurrent encoder, convolutional decoder)
#  * Grapheme2phoneme - convert words to transcripts
#
# We chose simplified __Hebrew->English__ machine translation for words and short phrases (character-level), as it is relatively quick to train even without a gpu cluster.

# %%
EASY_MODE = False        #If True, only translates phrases shorter than 20 characters (way easier).
                        #Useful for initial coding.
                        #If false, works with all phrases (please switch to this mode for homework assignment)

MODE = "he-to-en"                                # way we translate. Either "he-to-en" or "en-to-he"
MAX_OUTPUT_LENGTH = 50 if not EASY_MODE else 20  # maximal length of _generated_ output, does not affect training
REPORT_FREQ       = 100                          # how often to evaluate validation score

# %%
assert not EASY_MODE, "make sure you set EASY_MODE = False at the top of the notebook."

# %% [markdown]
# ### Step 1: preprocessing
#
# We shall store dataset as a dictionary
# `{ word1:[translation1,translation2,...], word2:[...],...}`.
#
# This is mostly due to the fact that many words have several correct translations.
#
# We have implemented this thing for you so that you can focus on more interesting parts.
#
#
# __Attention python2 users!__ You may want to cast everything to unicode later during homework phase, just make sure you do it _everywhere_.

# %%
import numpy as np
from collections import defaultdict
word_to_translation = defaultdict(list) #our dictionary

bos = '_'
eos = ';'

with open("main_dataset.txt") as fin:
    for line in fin:
        
        en,he = line[:-1].lower().replace(bos,' ').replace(eos,' ').split('\t')
        word,trans = (he,en) if MODE=='he-to-en' else (en,he)
        
        if len(word) < 3: continue
        if EASY_MODE:
            if max(len(word),len(trans))>20:
                continue
        
        word_to_translation[word].append(trans)
    
print ("size = ",len(word_to_translation))
# Out:
# size =  181801

# %%
#get all unique lines in source language
all_words = np.array(list(word_to_translation.keys()))
# get all unique lines in translation language
all_translations = np.array([ts for all_ts in word_to_translation.values() for ts in all_ts])

# %% [markdown]
# ### split the dataset
#
# We hold out 10% of all words to be used for validation.

# %%
from sklearn.model_selection import train_test_split
train_words,test_words = train_test_split(all_words,test_size=0.1,random_state=42)

# %% [markdown]
# ### Building vocabularies
#
# We now need to build vocabularies that map strings to token ids and vice versa. We're gonna need these fellas when we feed training data into model or convert output matrices into english words.

# %%
from voc import Vocab
inp_voc = Vocab.from_lines(''.join(all_words), bos=bos, eos=eos, sep='')
out_voc = Vocab.from_lines(''.join(all_translations), bos=bos, eos=eos, sep='')

# %%
# Here's how you cast lines into ids and backwards.
batch_lines = all_words[:5]
batch_ids = inp_voc.to_matrix(batch_lines)
batch_lines_restored = inp_voc.to_lines(batch_ids)

print("lines")
print(batch_lines)
print("\nwords to ids (0 = bos, 1 = eos):")
print(batch_ids)
print("\nback to words")
print(batch_lines_restored)
# Out:
# lines
# ['אנרכיזם' 'אוטיזם קלאסי' 'אלבדו' 'אלבמה' 'אכילס']
#
# words to ids (0 = bos, 1 = eos):
# [[  0 174 170 157 105 161  50   5   1   1   1   1   1   1]
#  [  0 174 126 112 161  50   5  48 189  40 174 164 161   1]
#  [  0 174  40  83 180 126   1   1   1   1   1   1   1   1]
#  [  0 174  40  83 134  51   1   1   1   1   1   1   1   1]
#  [  0 174 105 161  40 164   1   1   1   1   1   1   1   1]]
#
# back to words
# ['אנרכיזם', 'אוטיזם קלאסי', 'אלבדו', 'אלבמה', 'אכילס']

# %% [markdown]
# Draw word/translation length distributions to estimate the scope of the task.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=[8,4])
plt.subplot(1,2,1)
plt.title("words")
plt.hist(list(map(len,all_words)),bins=20);

plt.subplot(1,2,2)
plt.title('translations')
plt.hist(list(map(len,all_translations)),bins=20);

# %% [markdown]
# ### Step 3: deploy encoder-decoder (1 point)
#
# __assignment starts here__
#
# Our architecture consists of two main blocks:
# * Encoder reads words character by character and outputs code vector (usually a function of last RNN state)
# * Decoder takes that code vector and produces translations character by character
#
# Than it gets fed into a model that follows this simple interface:
# * __`model(inp, out, **flags) -> logp`__ - takes symbolic int32 matrices of hebrew words and their english translations. Computes the log-probabilities of all possible english characters given english prefices and hebrew word.
# * __`model.translate(inp, **flags) -> out, logp`__ - takes symbolic int32 matrix of hebrew words, produces output tokens sampled from the model and output log-probabilities for all possible tokens at each tick.
#   * if given flag __`greedy=True`__, takes most likely next token at each iteration. Otherwise samples with next token probabilities predicted by model.
#
# That's all! It's as hard as it gets. With those two methods alone you can implement all kinds of prediction and training.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
from lstm_model_torch_cuda import FullTranslationModel
model = FullTranslationModel(inp_voc, out_voc,
                              emb_size=64, hid_size=256)
model.cuda()
# Out:
# FullTranslationModel(
#   (emb_inp): Embedding(196, 64)
#   (emb_out): Embedding(325, 64)
#   (enc_bi_LSTM): LSTM(64, 256, batch_first=True, bidirectional=True)
#   (enc_LSTM): LSTM(512, 512, batch_first=True)
#   (dec_start_lower): Linear(in_features=512, out_features=512, bias=True)
#   (dec_start_upper): Linear(in_features=512, out_features=512, bias=True)
#   (dec_lower): GRUCell(64, 512)
#   (dec_upper): GRUCell(512, 512)
#   (logits): Linear(in_features=512, out_features=325, bias=True)
# )

# %%
# Play around with symbolic_translate and symbolic_score
inp = Variable(torch.LongTensor(np.random.randint(0,10,[3,5]))).cuda()
out = Variable(torch.LongTensor(np.random.randint(0,10,[3,5]))).cuda()

# translate inp (with untrained model)
sampled_out, logp = model.translate(inp, greedy=False)

print("Sample translations:\n", sampled_out)
print("Log-probabilities at each step:\n",logp)
# Out:
# Sample translations:
#  Variable containing:
#
# Columns 0 to 12
#     0   226   129   183    64   112   168    27    43   118   249   234   221
#     0   123   286   313    28   139   121   321    61   129    72   257   135
#     0     2   304   200   159    97    85   162    33    63   149    66   279
#
# Columns 13 to 25
#    50    87    38   306   250   109   116    43   169   300     1   197    32
#   292    40   152   191   115    15   320   104   287    14   168   143   291
#    99    79   215    85   127    85   115   277   213   287   283   185   192
#
# Columns 26 to 38
#   250   238   188   208   276   196   181     3   255   186   249   199    55
#   250   106    72    51    29    39   256   159   311   305   154   189     2
#    48    80   181   283    96   228   297   166   261   176   234    76   164
#
# Columns 39 to 51
#   219   258   142   267    40   104   249   105   241    13   234    63   269
#   120    98   130   248    92    71   252   279   108    45    78    50   184
#   116   218   259   254   271   152   283   311    43   170   202    43   167
#
# Columns 52 to 64
#   122   177   238   158   169   178   183   233   196    99   121   170    70
#    99     1    95   283   238    68   161    67   200   108   196    36   135
#   137   236   240    98   108   255   318   101   111    59   254   117     1
# [torch.cuda.LongTensor of size 3x65 (GPU 0)]
#
# Log-probabilities at each step:
#  Variable containing:
# ( 0 ,.,.) =
#    0.0000 -69.0776 -69.0776  ...  -69.0776 -69.0776 -69.0776
#   -5.7913  -5.7915  -5.7861  ...   -5.8372  -5.7947  -5.7474
#   -5.7943  -5.7960  -5.7665  ...   -5.8521  -5.8102  -5.7292
#             ...               ⋱              ...
#   -5.7314  -5.7904  -5.8549  ...   -5.7824  -5.8484  -5.7484
#   -5.7032  -5.7414  -5.8300  ...   -5.8469  -5.8320  -5.7442
#   -5.7216  -5.7532  -5.8107  ...   -5.8563  -5.8074  -5.7466
#
# ( 1 ,.,.) =
#    0.0000 -69.0776 -69.0776  ...  -69.0776 -69.0776 -69.0776
#   -5.7939  -5.8004  -5.7825  ...   -5.8441  -5.7911  -5.7496
#   -5.7772  -5.8035  -5.7927  ...   -5.8571  -5.7864  -5.7644
#             ...               ⋱              ...
#   -5.7739  -5.7789  -5.8361  ...   -5.8846  -5.7843  -5.7804
#   -5.7574  -5.8001  -5.8454  ...   -5.8581  -5.7953  -5.8016
#   -5.7555  -5.7937  -5.8338  ...   -5.8322  -5.8333  -5.7817
#
# ( 2 ,.,.) =
#    0.0000 -69.0776 -69.0776  ...  -69.0776 -69.0776 -69.0776
#   -5.7947  -5.7944  -5.7879  ...   -5.8374  -5.7936  -5.7469
#   -5.7819  -5.7893  -5.8063  ...   -5.8523  -5.7922  -5.7477
#             ...               ⋱              ...
#   -5.7623  -5.7885  -5.7851  ...   -5.7886  -5.8544  -5.7738
#   -5.7738  -5.8043  -5.7814  ...   -5.7945  -5.8527  -5.7666
#   -5.7875  -5.7635  -5.7805  ...   -5.7840  -5.8457  -5.7539
# [torch.cuda.FloatTensor of size 3x65x325 (GPU 0)]

# %%
# score logp(out | inp) with untrained input
logp = model(inp, out)
print("Symbolic_score output:\n", logp)

print("Log-probabilities of output tokens:\n", torch.gather(logp, dim=2, index=out[:,:,None]))
# Out:
# Symbolic_score output:
#  Variable containing:
# ( 0 ,.,.) =
#    0.0000 -69.0776 -69.0776  ...  -69.0776 -69.0776 -69.0776
#   -5.7880  -5.7907  -5.7953  ...   -5.7956  -5.8160  -5.7496
#   -5.7756  -5.7904  -5.7933  ...   -5.7867  -5.8075  -5.7565
#   -5.7735  -5.7906  -5.8131  ...   -5.7728  -5.7873  -5.7644
#   -5.7740  -5.7860  -5.8331  ...   -5.7614  -5.7732  -5.7690
#
# ( 1 ,.,.) =
#    0.0000 -69.0776 -69.0776  ...  -69.0776 -69.0776 -69.0776
#   -5.7848  -5.8110  -5.7961  ...   -5.8546  -5.8368  -5.7722
#   -5.7731  -5.8113  -5.8139  ...   -5.8314  -5.8207  -5.7678
#   -5.7675  -5.8150  -5.8044  ...   -5.8000  -5.8288  -5.7590
#   -5.7634  -5.8402  -5.7912  ...   -5.7788  -5.8369  -5.7590
#
# ( 2 ,.,.) =
#    0.0000 -69.0776 -69.0776  ...  -69.0776 -69.0776 -69.0776
#   -5.7969  -5.7676  -5.8247  ...   -5.8382  -5.8031  -5.7661
#   -5.7708  -5.7794  -5.8340  ...   -5.8245  -5.7978  -5.7688
#   -5.7596  -5.7793  -5.8300  ...   -5.8309  -5.8015  -5.7458
#   -5.7505  -5.8171  -5.8081  ...   -5.8014  -5.8115  -5.7423
# [torch.cuda.FloatTensor of size 3x5x325 (GPU 0)]
#
# Log-probabilities of output tokens:
#  Variable containing:
# (0 ,.,.) =
#  -69.0776
#   -5.7907
#   -5.7563
#   -5.7688
#   -5.7758
#
# (1 ,.,.) =
#  -69.0776
#   -5.7575
#   -5.6848
#   -5.7903
#   -5.7415
#
# (2 ,.,.) =
#  -69.0776
#   -5.7851
#   -5.8603
#   -5.7998
#   -5.8204
# [torch.cuda.FloatTensor of size 3x5x1 (GPU 0)]

# %%
def translate(lines, max_len=MAX_OUTPUT_LENGTH):
    """
    You are given a list of input lines. 
    Make your neural network translate them.
    :return: a list of output lines
    """
    # Convert lines to a matrix of indices
    lines_ix = inp_voc.to_matrix(lines)
    lines_ix = Variable(torch.LongTensor(lines_ix)).cuda()
    
    # Compute translations in form of indices
    trans_ix = model.translate(lines_ix, greedy=True, max_len=max_len)[0]
    
    # Convert translations back into strings
    return out_voc.to_lines(trans_ix.data.cpu().numpy())

# %%
print("Sample inputs:",all_words[:3])
print("Dummy translations:",translate(all_words[:3]))
trans = translate(all_words[:3])

assert translate(all_words[:3]) == translate(all_words[:3]), "make sure translation is deterministic (use greedy=True and disable any noise layers)"
assert type(translate(all_words[:3])) is list and (type(translate(all_words[:1])[0]) is str or type(translate(all_words[:1])[0]) is unicode), "translate(lines) must return a sequence of strings!"
# note: if translation freezes, make sure you used max_len parameter
print("Tests passed!")
# Out:
# Sample inputs: ['אנרכיזם' 'אוטיזם קלאסי' 'אלבדו']
# Dummy translations: ['ģංáá桜ááṃṃṃרṃרṃṃẓẓডʻʻ¡¡¡桜ζáá桜áṃṃחתẓẓডডõ♭τק4$4ρρρធẓ', 'í*白4ēţẓẓμডζbbbbzńה*:áááṃṃṃẓডʻ¡¡ṃṃחz¡¡áṃṃחẓẓডʻtρζρ', 'ģáááṃṃṃרṃẓẓডʻρζρ*ʿζʿáááá桜ṃáṃṃרṃרṃṃẓẓডʻʻ¡¡¡桜ζáá桜áṃ']
# Tests passed!

# %% [markdown]
# ### Scoring function
#
# LogLikelihood is a poor estimator of model performance.
# * If we predict zero probability once, it shouldn't ruin entire model.
# * It is enough to learn just one translation if there are several correct ones.
# * What matters is how many mistakes model's gonna make when it translates!
#
# Therefore, we will use minimal Levenshtein distance. It measures how many characters do we need to add/remove/replace from model translation to make it perfect. Alternatively, one could use character-level BLEU/RougeL or other similar metrics.
#
# The catch here is that Levenshtein distance is not differentiable: it isn't even continuous. We can't train our neural network to maximize it by gradient descent.

# %%
word_to_translation
# Out:
# defaultdict(list,
#             {'אנרכיזם': ['anarchism', 'hogeye/anarchism', 'dstuartnz/sandbox'],
#              'אוטיזם קלאסי': ['autism', 'wbtthefrog/sandbox/t32q4/autism'],
#              'אלבדו': ['albedo'],
#              'אלבמה': ['alabama'],
#              'אכילס': ['achilles', '588 achilles', 'achilles'],
#              'אברהם לינקולן': ['abraham lincoln'],
#              'אריסטו': ['aristotle'],
#              'אמריקאי בפריז': ['an american in paris', 'an american in paris'],
#              'פרס אוסקר': ['academy awards'],
#              'הזמן האטומי הבינלאומי': ['international atomic time'],
#              'זולתנות': ['altruism'],
#              'איין ראנד': ['ayn rand'],
#              "אלג'יריה": ['algeria'],
#              'אנתרופולוגיה': ['anthropology'],
#              'אגרונומיה': ['agricultural science', 'agronomy'],
#              'אלכימיה': ['alchemy'],
#              'אסטרונום': ['astronomer'],
#              'ascii': ['ascii'],
#              'אוסטין': ['austin',
#               'texas austin',
#               'austin',
#               'austin',
#               'austin',
#               'austin',
#               'austin',
#               'austin',
#               'austin',
#               'austin',
#               'austin',
#               'austin'],
#              'הנפשה': ['animation'],
#              'אפולו': ['apollo', 'apollo', 'apollo', 'apolo', 'apolo'],
#              'אנדרה אגאסי': ['andre agassi'],
#              'שפות אפרו-אסיאתיות': ['afroasiatic languages'],
#              'אנדורה': ['andorra', 'andorra', 'andorra'],
#              'ממוצע חשבוני': ['arithmetic mean'],
#              'american football conference': ['american football conference'],
#              'חוות החיות': ['animal farm', 'animal farm'],
#              'דו-חיים': ['amphibian'],
#              'אלסקה': ['alaska', 'alaska'],
#              'חקלאות': ['agriculture'],
#              'אלדוס האקסלי': ['aldous huxley'],
#              'עדה': ['ada', 'ada', 'ada', 'ada'],
#              'אברדין': ['aberdeen',
#               'aberdeen',
#               'washington aberdeen',
#               'aberdeen f.c.'],
#              'אצות': ['algae'],
#              'אלקאן': ['alkane'],
#              'טכנולוגיה מסייעת': ['assistive technology'],
#              'חשבונייה': ['abacus'],
#              'חומצה': ['acid'],
#              'אספלט': ['asphalt'],
#              'מכון התקנים האמריקני': ['american national standards institute'],
#              'אפולו 11': ['apollo 11'],
#              'אפולו 8': ['apollo 8'],
#              'טייס חלל': ['astronaut'],
#              'הצעה צנועה': ['a modest proposal'],
#              'מתכת אלקלית': ['alkali metal'],
#              'אלפבית': ['alphabet', 'alphabet'],
#              'מספר אטומי': ['atomic number'],
#              'אנטומיה': ['anatomy'],
#              'אישור הסוגר': ['affirming the consequent'],
#              'אנדריי טרקובסקי': ['andrei tarkovsky'],
#              'עמימות': ['ambiguity'],
#              'שנבוב': ['aardvark'],
#              'צבועון הרעמה': ['aardwolf'],
#              'טיט': ['adobe'],
#              'הרפתקה': ['adventure'],
#              'אסיה': ['asia', 'asia', 'asia', 'assia'],
#              'ארובה': ['aruba', 'chimney', 'aruba'],
#              'תקנון הקונפדרציה': ['articles of confederation'],
#              'האוקיינוס האטלנטי': ['atlantic ocean', 'fishfab'],
#              'ארתור שופנהאואר': ['arthur schopenhauer'],
#              'אנגולה': ['angola'],
#              "אלברט סידני ג'ונסטון": ['albert sidney johnston'],
#              'אנדרואיד': ['android', 'android', 'android'],
#              'אלברטה': ['alberta', 'alberta'],
#              'מקריני סנפיר': ['actinopterygii'],
#              'אלברט איינשטיין': ['albert einstein'],
#              'אפגניסטן': ['afghanistan'],
#              'אלבניה': ['albania'],
#              'אללה': ['allah'],
#              "אזרבייג'ן": ['azerbaijan', 'azerbaijan'],
#              'אסטרונומיית חובבים': ['amateur astronomy'],
#              'אייקידו': ['aikido'],
#              'אמנות': ['art', 'art'],
#              'הפלה מלאכותית': ['abortion'],
#              'מלחמת העצמאות של ארצות הברית': ['american revolutionary war'],
#              'אמפר': ['ampere'],
#              'אלגוריתם': ['algorithm', 'csfypwaiting'],
#              'אטלס': ['atlas',
#               'atlas',
#               'atlas',
#               'atlas',
#               'atlas',
#               'atlas',
#               'atlas'],
#              'שטיפת פה': ['mouthwash'],
#              'אלכסנדר הגדול': ['alexander the great', 'alexander the great'],
#              "אלפרד קוז'יבסקי": ['alfred korzybski'],
#              'אסטרואידים': ['asteroids'],
#              'אספרגאים': ['asparagales'],
#              'כף צפרדע': ['alismatales'],
#              'סוככאים': ['apiales'],
#              'אסטראים': ['asterales'],
#              'אסטרואיד': ['asteroid'],
#              'תצהיר': ['affidavit'],
#              'טלה': ['aries', 'aries'],
#              'דלי': ['aquarius', 'bucket', 'aquarius'],
#              'אנימה': ['anime', 'ænima', 'anima', 'anima and animus'],
#              'אנקרה': ['ankara', 'ankara province'],
#              'ערבית': ['arabic'],
#              "אלפרד היצ'קוק": ['alfred hitchcock'],
#              'שפות אלטאיות': ['altaic languages'],
#              'אקסיומת הבחירה': ['axiom of choice'],
#              'אטילה ההוני': ['attila'],
#              'הים האגאי': ['aegean sea', 'aegean region'],
#              'תפוז מכני': ['a clockwork orange', 'a clockwork orange'],
#              'אמסטרדם': ['amsterdam', 'amsterdam', 'amsterdam'],
#              'אאודי': ['audi'],
#              'כלי טיס': ['aircraft'],
#              'אלפרד נובל': ['alfred nobel'],
#              'אלכסנדר גרהם בל': ['alexander graham bell'],
#              'אפל': ['apple inc.', 'apple', 'appel', 'apple'],
#              'מלחמת האזרחים האמריקנית': ['american civil war',
#               'jimmuldrow/sandbox',
#               'armyant/sandbox'],
#              'אנדי וורהול': ['andy warhol'],
#              'אלפ ארסלאן': ['alp arslan'],
#              'מכון הסרטים האמריקאי': ['american film institute'],
#              'אקירה קורוסאווה': ['akira kurosawa'],
#              'מצרים העתיקה': ['ancient egypt'],
#              "אבג'ד": ['abjad'],
#              'אבוגידה': ['abugida'],
#              'אבבא': ['abba'],
#              'אלפרד אלטון ואן ווגט': ['a. van vogt'],
#              'אנה קורניקובה': ['anna kournikova'],
#              'אגנוסטיות': ['agnosticism'],
#              'ארגון': ['argon',
#               'organization',
#               'diloreto/sandbox',
#               'organizing'],
#              'ארסן': ['arsenic', 'arsen'],
#              'אנטימון': ['antimony'],
#              'אקטיניום': ['actinium'],
#              'אמריציום': ['americium'],
#              'אסטטין': ['astatine'],
#              'אטום': ['atom', 'atom', 'atom'],
#              'אלומיניום': ['aluminium'],
#              'השיתוף האנגליקני': ['anglican communion'],
#              'ארכיפלג': ['archipelago'],
#              'מחבר': ['author'],
#              'אנדריי מרקוב': ['andrey markov'],
#              'ייאוש': ['angst', 'yiush'],
#              'חרדה': ['anxiety'],
#              'אלן אלכסנדר מילן': ['a. milne'],
#              'אקסיומה': ['axiom'],
#              'אלפא': ['alpha', 'alpha', 'alpha', 'alpha group', 'alpha'],
#              'אלווין טופלר': ['alvin toffler'],
#              'אנטיגואה וברבודה': ['antigua and barbuda'],
#              'אלברט שפר': ['albert speer'],
#              'מורכבים': ['asteraceae'],
#              'סוככיים': ['apiaceae'],
#              'אקסון': ['axon', 'exon', 'exon'],
#              'אלפבית ארמי': ['aramaic alphabet'],
#              'אטקסיה': ['ataxia'],
#              'עדה לאבלייס': ['ada lovelace'],
#              'הרי האלפים': ['alps'],
#              'אלבר קאמי': ['albert camus'],
#              'אגאתה כריסטי': ['agatha christie'],
#              'הדבר': ['the plague', 'thing'],
#              'ערך מוחלט': ['absolute value'],
#              'דקלאים': ['arecales'],
#              'הרקול פוארו': ['hercule poirot'],
#              "ג'יין מארפל": ['miss marple'],
#              'אפריל': ['april', 'april', 'april'],
#              'אוגוסט': ['august', 'august', 'august', 'august'],
#              'אהרן': ['aaron',
#               'aaron',
#               'aaron',
#               'aaron',
#               'aaron',
#               'aharon',
#               'aharon',
#               'aharon',
#               'aharon',
#               'aharon',
#               'aharon',
#               'aharon',
#               'aharon',
#               'aharon',
#               'aharon',
#               'aharon',
#               'aharon',
#               'ahern',
#               'ahron',
#               'ahron'],
#              '6 באפריל': ['april 6'],
#              '12 באפריל': ['april 12'],
#              '15 באפריל': ['april 15'],
#              '30 באפריל': ['april 30'],
#              '22 באוגוסט': ['august 22'],
#              '27 באוגוסט': ['august 27'],
#              'כוהל': ['alcohol'],
#              'אלן גינסברג': ['allen ginsberg'],
#              'שדה סגור אלגברית': ['algebraically closed field'],
#              '6 באוגוסט': ['august 6'],
#              'אנטולי קרפוב': ['anatoly karpov'],
#              'מרוץ מכוניות': ['auto racing'],
#              'אנרכו-קפיטליזם': ['anarcho-capitalism'],
#              '9 באוגוסט': ['august 9'],
#              'אריסטופאנס': ['aristophanes'],
#              'אלברט שווייצר': ['albert schweitzer'],
#              'האסכולה האוסטרית': ['austrian school'],
#              'מורסה': ['abscess'],
#              'אורהוס': ['aarhus'],
#              'אלכסיס קארל': ['alexis carrel'],
#              'יום כל הנשמות': ["all souls' day"],
#              'אנטול פראנס': ['anatole france'],
#              "אנדרה ז'יד": ['andré gide'],
#              'שקד מצוי': ['almond'],
#              'אנטישמיות': ['antisemitism'],
#              'פוליטיקה של סמואה האמריקנית': ['politics of american samoa'],
#              '13 באוגוסט': ['august 13'],
#              'אבן סינא': ['avicenna'],
#              'אנליזה': ['analysis', 'analysis'],
#              'אפנון משרעת': ['amplitude modulation'],
#              "אוגוסטן ז'אן פרנל": ['augustin-jean fresnel'],
#              'אב מנזר': ['abbot'],
#              'ארדיפיתקוס': ['ardipithecus'],
#              'פס ייצור': ['assembly line'],
#              'אדלייד': ['adelaide', 'adelaide island'],
#              '2 באוגוסט': ['august 2'],
#              'אטלנטיק': ['atlantic'],
#              'מספר אלגברי': ['algebraic number'],
#              'אוטומורפיזם': ['automorphism'],
#              'אקורדיון': ['accordion'],
#              'בינה מלאכותית': ['artificial intelligence',
#               'rich farmbrough/temp59'],
#              'אנכסימנדרוס': ['anaximander'],
#              'אדריכל': ['architect'],
#              'אפרודיטה': ['aphrodite', 'aphrodite'],
#              '1 באפריל': ['april 1'],
#              'יחס אנטי-סימטרי': ['antisymmetric relation'],
#              'אליסטר קראולי': ['aleister crowley'],
#              'חיים לאחר המוות': ['afterlife'],
#              'אתנה': ['athena', 'athena'],
#              'סגסוגת': ['alloy'],
#              'זווית': ['angle'],
#              'אסא': ['asa', 'asa of judah', 'asa', 'asa'],
#              'אקוסטיקה': ['acoustics'],
#              'פיזיקה אטומית': ['atomic physics',
#               'random2382908/draft atomic physics'],
#              'יישומון': ['applet'],
#              'היסטוריה חלופית': ['alternate history'],
#              'אורביטל אטומי': ['atomic orbital',
#               'csmallw/sandbox',
#               'csmallw/sandbox'],
#              'חומצת אמינו': ['amino acid'],
#              'אלן טיורינג': ['alan turing'],
#              'שטח': ['area'],
#              'יחידה אסטרונומית': ['astronomical unit'],
#              'אמן': ['artist',
#               'amen',
#               'netherlands emmen',
#               'amen.',
#               'amen',
#               'artist'],
#              'אקטיון': ['actaeon'],
#              'אתונה': ['athens'],
#              'אנגווילה': ['anguilla'],
#              'איי אשמור וקרטייה': ['ashmore and cartier islands'],
#              'אלכסנדר מקנזי': ['alexander mackenzie'],
#              'אשוקה': ['ashoka'],
#              'אלפונסו קוארון': ['alfonso cuarón'],
#              'אריאניות': ['arianism'],
#              '1 באוגוסט': ['august 1'],
#              'אנטונינוס פיוס': ['antoninus pius'],
#              '3 באוגוסט': ['august 3'],
#              'advanced encryption standard': ['advanced encryption standard'],
#              '26 באפריל': ['april 26'],
#              'אנאיזוטרופיות': ['anisotropy'],
#              'קרינת אלפא': ['alpha decay',
#               'edivorce/dusandbox',
#               'nitpicker769/sandbox'],
#              'מנוע אנליטי': ['analytical engine'],
#              'אוגוסטוס קיסר': ['augustus'],
#              'הברית האנטארקטית': ['antarctic treaty system'],
#              'the alan parsons project': ['the alan parsons project'],
#              'כמעט כל': ['almost all'],
#              'אסכולת האנאל': ['annales school'],
#              'אנטי-חומר': ['antimatter', '12onetwothreefour/anti mass'],
#              'קאזה באליו': ['casa batlló'],
#              'פארק גואל': ['park güell'],
#              'קאזה מילה': ['casa milà'],
#              'אנטי-חלקיק': ['antiparticle'],
#              '7 באוגוסט': ['august 7'],
#              '8 באוגוסט': ['august 8'],
#              '16 באפריל': ['april 16'],
#              'פעולה אסוציאטיבית': ['associative property'],
#              "קרן התוכנה אפאצ'י": ['apache software foundation'],
#              'apple i': ['apple i'],
#              'אפטוזאורוס': ['apatosaurus'],
#              'אלוזאורוס': ['allosaurus'],
#              'ak-47': ['ak-47'],
#              'מחשב אתנסוף ברי': ['atanasoff–berry computer'],
#              'הרי האנדים': ['andes'],
#              'עוגן': ['anchor'],
#              'פירוז שבור': ['anbar'],
#              'אנגרמה': ['anagram'],
#              'אנדרה מרי אמפר': ['andré-marie ampère'],
#              'אמוניה': ['ammonia'],
#              'אחלמה': ['amethyst'],
#              'אלברטוזאורוס': ['albertosaurus'],
#              'שפת סף': ['assembly language'],
#              'אמברוסיה ונקטר': ['ambrosia'],
#              'אמברוזיוס': ['ambrose'],
#              'אמפראקיה': ['ambracia'],
#              'ענבר': ['amber', 'inbar', 'inbar'],
#              'קרן האלפים': ['alphorn'],
#              'צבא יבשה': ['army'],
#              'אליגטוריים': ['alligatoridae'],
#              'אלנוס': ['alder'],
#              'ארכנופוביה': ['arachnophobia', 'arachnophobia'],
#              'אלבסטר': ['alabaster'],
#              'אחאב': ['ahab'],
#              'אגוטיים': ['dasyproctidae'],
#              'אלגול': ['algol', 'algol'],
#              'amazing grace': ['amazing grace'],
#              'אמריקה און ליין': ['aol'],
#              'ספירת הנוצרים': ['anno domini'],
#              'אלקואין': ['alcuin'],
#              'אמין': ['amine', 'amin', 'emin'],
#              '29 באפריל': ['april 29'],
#              '14 באוגוסט': ['august 14'],
#              'האפס המוחלט': ['absolute zero'],
#              'תהליך אדיאבטי': ['adiabatic process'],
#              'אמיד': ['amide'],
#              'אנימיזם': ['animism'],
#              'אנטוניו ויוואלדי': ['antonio vivaldi'],
#              'ארה': ['aare', 'ara', 'aargletschers', 'aare', 'era'],
#              'אברהם': ['abraham',
#               'abraham',
#               'abraham gonzález',
#               'abraham',
#               'abraham',
#               'abraham',
#               'abraham',
#               'abraham',
#               'abraham',
#               'abraham',
#               'abraham',
#               'abraham',
#               'abraham',
#               'abraham',
#               'avi',
#               'avi',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avraham',
#               'avram',
#               'avram',
#               'avrohom'],
#              'אבשלום': ['absalom',
#               'absalom',
#               'israel avshalom',
#               'sinai avshalom',
#               'avshalom',
#               'avshalom',
#               'avshalom',
#               'avshalom'],
#              'אבידוס': ['abydos', 'egypt abydos', 'abydos'],
#              '15 באוגוסט': ['august 15'],
#              'אקפולקו': ['acapulco'],
#              '16 באוגוסט': ['august 16'],
#              'algol': ['algol'],
#              'awk': ['awk'],
#              'אסגארד': ['asgard'],
#              'תוכנית אפולו': ['apollo program'],
#              'תקיפה': ['assault', 'assault'],
#              'אלמאנים': ['alemanni'],
#              '17 באוגוסט': ['august 17'],
#              '12 באוגוסט': ['august 12'],
#              'אלפרד ראסל וולאס': ['alfred russel wallace'],
#              'מפלגת הלייבור האוסטרלית': ['australian labor party'],
#              '18 באוגוסט': ['august 18'],
#              '19 באוגוסט': ['august 19'],
#              '21 באוגוסט': ['august 21'],
#              'אלברט': ['albert',
#               'albert',
#               'albert',
#               'albert',
#               'albert',
#               'albert',
#               'albert',
#               'albert',
#               'albert',
#               'albert',
#               'albert',
#               'albert',
#               'albert',
#               'of'],
#              'אלברט הראשון': ['albert i'],
#              'אלברכט מברנדנבורג': ['albert of brandenburg'],
#              '25 באוגוסט': ['august 25'],
#              'אאכן': ['aachen'],
#              'אגט': ['agate'],
#              'אספירין': ['aspirin', 'beetstra/aspirin'],
#              'אבנר בן נר': ['abner'],
#              'אהמט הראשון': ['ahmed i'],
#              'אהמט השני': ['ahmed ii'],
#              'אהמט השלישי': ['ahmed iii'],
#              'איינו': ['ainu people', 'ainu languages'],
#              'אקרופוליס': ['acropolis', 'acropolis'],
#              'דיקור סיני': ['acupuncture'],
#              'איניאס': ['aeneas'],
#              '13 באפריל': ['april 13'],
#              'ירבוז': ['amaranth'],
#              'אגממנון': ['agamemnon'],
#              'אגסילאוס השני': ['agesilaus ii'],
#              'אגריפינה': ['agrippina the elder'],
#              'אחמד שאה דוראני': ['ahmad shah durrani'],
#              'האימפריה האכדית': ['akkadian empire'],
#              'איאס': ['ajax', 'ajax'],
#              'ajax': ['ajax', 'ajax', 'fatalerror/ajax'],
#              'אלאריק הראשון': ['alaric i'],
#              'אלברטוס מגנוס': ['albertus magnus'],
#              'אלבוין': ['alboin'],
#              'אפונסו דה אלבוקרקי': ['afonso de albuquerque'],
#              'אלקאיוס': ['alcaeus of mytilene'],
#              'אלקמנה': ['alcmene'],
#              'אלכסנדר באלאס': ['alexander balas'],
#              'מלך אפירוס אלכסנדר השני': ['alexander ii of epirus'],
#              'אלכסנדר יגיילו': ['alexander jagiellon'],
#              'קיסר רוסיה אלכסנדר השלישי': ['alexander iii of russia'],
#              'מלך סקוטלנד אלכסנדר הראשון': ['alexander i of scotland'],
#              'מלך סקוטלנד אלכסנדר השני': ['alexander ii of scotland'],
#              'מלך סרביה אלכסנדר הראשון': ['alexander i of serbia'],
#              'מלך סקוטלנד אלכסנדר השלישי': ['alexander iii of scotland'],
#              'אלכסנדר סוורוס': ['severus alexander'],
#              'אלכסנדר הראשון': ['alexander i', 'pope alexander i'],
#              'אלכסנדר השני': ['alexander ii', 'alexander of judaea'],
#              'אלכסנדר השלישי': ['alexander iii',
#               'pope alexander iii',
#               'russian battleship imperator aleksandr iii'],
#              'אלכסנדר ינאי': ['alexander jannaeus'],
#              'קיסר האימפריה הביזנטית אלכסיוס הראשון': ['alexios i komnenos'],
#              'אלכסיי רומנוב': ['tsarevich of russia alexei petrovich'],
#              "אנדרו ג'קסון": ['andrew jackson'],
#              "אנדרו ג'ונסון": ['andrew johnson'],
#              "אלכסנדר סולז'ניצין": ['aleksandr solzhenitsyn'],
#              '23 באוגוסט': ['august 23'],
#              '24 באוגוסט': ['august 24'],
#              'אנטי-אפיפיור': ['antipope'],
#              'חקלאות ימית': ['aquaculture'],
#              'סיבוכיות קולמוגורוב': ['kolmogorov complexity'],
#              '28 באפריל': ['april 28'],
#              'אלפרד הגדול': ['alfred the great'],
#              "אלג'יר": ['algiers'],
#              "אבן אל-היית'ם": ['alhazen'],
#              'מוראביטון': ['almoravid dynasty', 'murabitun'],
#              'אלווי': ['aloe'],
#              'אליאטס': ['alyattes of lydia'],
#              'גיל ההסכמה': ['age of consent'],
#              'מלך פורטוגל אפונסו הראשון': ['afonso i of portugal'],
#              'מלך פורטוגל אפונסו החמישי': ['afonso v of portugal'],
#              'מלך פורטוגל אפונסו השישי': ['afonso vi of portugal'],
#              'מלך ספרד אלפונסו השנים עשר': ['alfonso xii of spain'],
#              'מלך ספרד אלפונסו השלושה עשר': ['alfonso xiii of spain'],
#              'מלך אראגון אלפונסו הראשון': ['alfonso the battler'],
#              'אמריליס יפהפה': ['amaryllis'],
#              'אלפונסו הראשון': ['alfonso i'],
#              'משפחת אמאטי': ['amati'],
#              'אמזונה': ['amazons', 'amazon parrot'],
#              'ענבר אפור': ['ambergris'],
#              'אמביוריקס': ['ambiorix'],
#              'אמזונאס': ['amazon river', 'amazonas', 'amazonas'],
#              '22 באפריל': ['april 22'],
#              '31 באוגוסט': ['august 31'],
#              'אבו בכר': ['abu bakr', 'abu bakr', 'mohammad adil/sandbox10'],
#              'עמון': ['ammon'],
#              'אמפיפוליס': ['amphipolis'],
#              'עמרם': ['amram', 'amram', 'amram'],
#              'אנכארסיס': ['anacharsis'],
#              'אנכסגורס': ['anaxagoras'],
#              'אנקסארכוס': ['anaxarchus'],
#              'אנסטסיוס הראשון': ['anastasius i', 'pope anastasius i'],
#              'אנסטסיוס השני': ['anastasius ii', 'pope anastasius ii'],
#              'אנסטסיוס': ['anastasius'],
#              'אנכסימנס': ['anaximenes of miletus'],
#              'אנקוס מארקיוס': ['ancus marcius'],
#              'אנדוקידס': ['andocides'],
#              'מלך הונגריה אנדראש השני': ['andrew ii of hungary'],
#              'אמיאנוס מרקלינוס': ['ammianus marcellinus'],
#              'אפולו 13': ['apollo 13', 'apollo 13'],
#              'אפולו 7': ['apollo 7'],
#              'אפולו 9': ['apollo 9', 'andicat/playground'],
#              'דלקת מפרקים': ['arthritis'],
#              '2 באפריל': ['april 2'],
#              'אצטילן': ['acetylene'],
#              'אלפרד': ['alfred',
#               'alfred',
#               'alfred',
#               'alfred',
#               'alfred',
#               'alfred',
#               'alfred'],
#              '28 באוגוסט': ['august 28'],
#              'הדמוקרטיה האתונאית': ['athenian democracy'],
#              'ספרות הודיות-ערביות': ['arabic numerals'],
#              '9 באפריל': ['april 9'],
#              'לוקיוס אפוליאוס': ['apuleius'],
#              'אלכסנדר סלקירק': ['alexander selkirk'],
#              'טיל נגד טילים': ['anti-ballistic missile'],
#              '29 באוגוסט': ['august 29'],
#              '30 באוגוסט': ['august 30'],
#              'אקר': ['acre', 'acker', 'acker'],
#              'atp': ['adenosine triphosphate'],
#              'אגיר': ['ægir'],
#              'אנטיביוטיקה': ['antibiotics', 'cutelittleboyboy'],
#              'ארנולד שוורצנגר': ['arnold schwarzenegger'],
#              'אדם סמית': ['adam smith'],
#              'אנטואן לבואזיה': ['antoine lavoisier'],
#              '18 באפריל': ['april 18'],
#              '23 באפריל': ['april 23', 'sixate7'],
#              "אמיטאב באצ'אן": ['amitabh bachchan'],
#              'אלופון': ['allophone'],
#              'מוספית': ['affix'],
#              'אלגוריה': ['allegory'],
#              'אלוטרופיה': ['allotropy'],
#              'אוגוסטן לואי קושי': ['augustin-louis cauchy'],
#              'ארכימדס': ['archimedes'],
#              'רפואה אלטרנטיבית': ['alternative medicine'],
#              'פאון ארכימדי': ['archimedean solid'],
#              'אנטי-מנסרה': ['antiprism'],
#              'הצבעת אישור': ['approval voting'],
#              'אוניברסיטת המדינה של אריזונה': ['arizona state university'],
#              '14 באפריל': ['april 14'],
#              "אלפרד ז'ארי": ['alfred jarry'],
#              'אמלריך': ['amalric'],
#              'מלך ירושלים אמלריך הראשון': ['amalric of jerusalem'],
#              'מלך ירושלים אמלריך השני': ['aimery of cyprus'],
#              'אר דקו': ['art deco'],
#              'אמנות ascii': ['ascii art'],
#              'אנגלית אמריקנית': ['american english'],
#              'האלפבית של אפריקה': ['africa alphabet'],
#              'אנגלית אוסטרלית': ['australian english'],
#              'טיסה 77 של אמריקן איירליינס': ['american airlines flight 77'],
#              'מארב': ['ambush', "ma'rib governorate"],
#              'נוגדן קטליטי': ['abzyme'],
#              'אלל': ['allele', 'aponeurosis', 'threelovemonkeys/sandbox'],
#              'אמפיצילין': ['ampicillin'],
#              'עמידות לאנטיביוטיקה': ['antimicrobial resistance'],
#              'אנטיגן': ['antigen'],
#              'אוטוזום': ['autosome'],
#              'אל-קאעידה': ['al-qaeda'],
#              'אלסנדרו וולטה': ['alessandro volta'],
#              'אנדרומדה': ['andromeda', 'andromeda', 'andromeda', 'andromeda'],
#              'משאבה': ['antlia', 'pump'],
#              'מזבח': ['ara', 'altar', 'altar'],
#              'ארקנסו': ['arkansas', 'arkansas river'],
#              'ציפור גן עדן': ['apus', 'strelitzia reginae', 'apus'],
#              'אבאדאן': ['iran abadan'],
#              'אלכסנדר פלמינג': ['alexander fleming'],
#              'אנדרו קרנגי': ['andrew carnegie'],
#              'עיצורים מקורבים': ['approximant consonant'],
#              'האסטרונום המלכותי': ['astronomer royal'],
#              'חברת תעופה': ['airline'],
#              'טריטוריית הבירה האוסטרלית': ['australian capital territory'],
#              'אלי מקביל': ['ally mcbeal'],
#              'האיגוד האמריקאי לחירויות אזרחיות': ['american civil liberties union'],
#              'אדובי מערכות': ['adobe systems'],
#              'שיטת אלכסנדר': ['alexander technique'],
#              'בהירות': ['apparent magnitude'],
#              'בהירות מוחלטת': ['absolute magnitude'],
#              'אפולו 1': ['apollo 1'],
#              'אפולו 10': ['apollo 10'],
#              'אפולו 12': ['apollo 12'],
#              'אפולו 14': ['apollo 14'],
#              'אפולו 15': ['apollo 15'],
#              'אפולו 16': ['apollo 16'],
#              'אפולו 17': ['apollo 17'],
#              'המהפכה האמריקאית': ['american revolution'],
#              '17 באפריל': ['april 17'],
#              'אלן אייקבורן': ['alan ayckbourn'],
#              'אלפא קנטאורי': ['alpha centauri'],
#              'קומודור אמיגה': ['amiga', 'orion blastar~enwiki/amiga'],
#              'אבל ינזון טסמן': ['abel tasman'],
#              '5 באוגוסט': ['august 5'],
#              'גאומטריה אלגברית': ['algebraic geometry'],
#              'אושוויץ': ['auschwitz concentration camp'],
#              'קשתות': ['archery'],
#              'אלוור אלטו': ['alvar aalto'],
#              "אלפרד ג'ולס אייר": ['a. ayer'],
#              'אנדרה וייל': ['andré weil'],
#              'אכאים': ['achaeans'],
#              'אטלה סלברג': ['atle selberg'],
#              'אייסכילוס': ['aeschylus'],
#              'דרך הענבר': ['amber road'],
#              'אנדרו ויילס': ['andrew wiles'],
#              'אן ברונטה': ['anne brontë'],
#              'אוגוסטינוס': ['augustine of hippo'],
#              'משחק': ['acting', 'game'],
#              'הליגה האטית-דלית': ['delian league'],
#              'אוגוסט הורך': ['august horch'],
#              'אוויוניקה': ['avionics'],
#              'ארס': ['ares', 'venom', 'ares', 'ares'],
#              'אלכסנדר גרותנדיק': ['alexander grothendieck'],
#              'אלכוהוליסטים אנונימיים': ['alcoholics anonymous',
#               'kellymin/sandbox/aa'],
#              'מערך': ['array data structure', 'formation'],
#              'המנון אוסטרליה': ['advance australia fair'],
#              "אמריגו וספוצ'י": ['amerigo vespucci',
#               'italian training ship amerigo vespucci'],
#              'אריסטיד מאיול': ['aristide maillol'],
#              'אנטוניו קנובה': ['antonio canova'],
#              'אוגוסט רודן': ['auguste rodin'],
#              'אן ארבור': ['michigan ann arbor'],
#              'חוק ההסדר 1701': ['act of settlement 1701'],
#              'חטיפת מטוס': ['aircraft hijacking'],
#              'האקרופוליס באתונה': ['acropolis of athens'],
#              'אווירונאוטיקה': ['aeronautics'],
#              'האחים לומייר': ['auguste and louis lumière'],
#              'מעשי השליחים': ['acts of the apostles'],
#              'אשור': ['assyria', 'beech', 'ashur', 'assur', 'ashur', 'ashur'],
#              'אביה': ['abijah', 'abijah of judah', 'euboea'],
#              'אפאזיה': ['aphasia'],
#              'אבי העורקים': ['aorta'],
#              'אבימלך מלך גרר': ['abimelech'],
#              'אסטריקס': ['asterix',
#               'astrix',
#               'අනංගයා/කෙළින තැන(sand box)',
#               'astrix'],
#              'אריזונה קרדינלס': ['arizona cardinals'],
#              'אטלנטה פלקונס': ['atlanta falcons'],
#              'אדלברט מפראג': ['adalbert of prague'],
#              'אלגברה': ['associative algebra', 'algebra', 'algebra'],
#              'אקסיומת היסוד': ['axiom of regularity'],
#              'ibm aix': ['ibm aix'],
#              'appletalk': ['appletalk'],
#              'apple ii': ['apple ii series'],
#              'apple iii': ['apple iii'],
#              'עץ avl': ['avl tree'],
#              'אליפטיות': ['aliphatic compound'],
#              'אסטרולוגיה': ['astrology', 'peterstrempel/astrology-sandbox'],
#              'אני דיפרנקו': ['ani difranco'],
#              'אריזונה דיאמונדבקס': ['arizona diamondbacks'],
#              'אסתטיקה': ['aesthetics'],
#              'ארון הברית': ['ark of the covenant'],
#              'אטלנטה ברייבס': ['atlanta braves'],
#              'אליה': ['aaliyah', 'tail fat', 'elia'],
#              'שריון': ['armour'],
#              'רכב קרבי משוריין': ['armoured fighting vehicle'],
#              'אנטון דרקסלר': ['anton drexler'],
#              'במערב אין כל חדש': ['all quiet on the western front',
#               'all quiet on the western front',
#               'all quiet on the western front'],
#              'אפרו-אמריקאים': ['african americans'],
#              'אפריקאנס': ['afrikaans'],
#              'איולוס': ['aeolus'],
#              'abc': ['abc', 'american broadcasting company', 'abc', 'abc'],
#              'ארסנל': ['arsenal f.c.', 'arsenal'],
#              'המטבח של ארצות הברית': ['cuisine of the united states'],
#              'אחמד שאה מסעוד': ['ahmad shah massoud'],
#              'אטלנטיס': ['atlantis',
#               'german auxiliary cruiser atlantis',
#               'atlantis',
#               'atlantis'],
#              'אוטוביוגרפיה': ['autobiography'],
#              'קיסר האימפריה הביזנטית ארקדיוס': ['arcadius'],
#              'ערבים': ['arabs'],
#              'אנטישמיות בעולם הערבי': ['antisemitism in the arab world'],
#              '11 באוגוסט': ['august 11'],
#              'ארקולוגיה': ['arcology'],
#              '5 באפריל': ['april 5'],
#              '20 באפריל': ['april 20'],
#              '19 באפריל': ['april 19'],
#              'עבד אל-עזיז אל-עומארי': ['abdulaziz al-omari'],
#              'אגה בוהר': ['aage bohr'],
#              'גאומטריה אנליטית': ['analytic geometry'],
#              'אלפבית ערבי': ['arabic alphabet',
#               'modus vivendi/arabic alphabet'],
#              'שועל שלג': ['arctic fox'],
#              'אבו סיאף': ['abu sayyaf'],
#              'ארמנית': ['armenian language'],
#              'נושאת מטוסים': ['aircraft carrier'],
#              'נבגוניות': ['apicomplexa'],
#              'המטבח הארגנטינאי': ['argentine cuisine'],
#              '8 באפריל': ['april 8'],
#              'אד הומינם': ['ad hominem'],
#              'אטארי': ['atari'],
#              'האנטי-אפיפיור יוחנן העשרים ושלושה': ['antipope john xxiii'],
#              'אנטוניו סליירי': ['antonio salieri'],
#              'שיכוך כאב': ['analgesic'],
#              'אייאקס': ['afc ajax', 'ajax'],
#              'ארתור אדינגטון': ['arthur eddington'],
#              '3 באפריל': ['april 3'],
#              'אלכסיס קורנר': ['alexis korner'],
#              'תותח סער': ['assault gun'],
#              'משחית טנקים': ['tank destroyer'],
#              'שריונית': ['armored car'],
#              'א.ז. אלקמאר': ['az alkmaar'],
#              'בלוטת יותרת הכליה': ['adrenal gland'],
#              'ארמית': ['aramaic language'],
#              'טיטוס': ['saint titus', 'titus', 'titus'],
#              'אקטיניד': ['actinide'],
#              'ארתור מילר': ['arthur miller'],
#              'אנטון דיאבלי': ['anton diabelli'],
#              'אניטה היל': ['anita hill'],
#              '10 באוגוסט': ['august 10'],
#              'אזור 51': ['area 51'],
#              'עיבוד אותות קול': ['audio signal processing'],
#              'חוק אמדל': ["amdahl's law"],
#              '27 באפריל': ['april 27'],
#              'איוואסקה': ['ayahuasca'],
#              'מספר אבה': ['abbe number'],
#              'עלייתה ונפילתה של העיר מהגוני': ['rise and fall of the city of mahagonny'],
#              'פליקס השני': ['antipope felix ii'],
#              'אלקלואיד': ['alkaloid'],
#              'אדוונטיזם': ['adventism'],
#              'הארכיבישוף מקנטרברי': ['archbishop of canterbury'],
#              'טיפוס נתונים מופשט': ['abstract data type'],
#              'רומא': ['a.s. roma', 'rome', 'roma', 'rome', 'province of rome'],
#              'ארגון אבו נידאל': ['abu nidal organization'],
#              'נוגדן': ['antibody'],
#              'אלסנדרו סקרלטי': ['alessandro scarlatti'],
#              'אסטון מרטין': ['aston martin'],
#              'אלברט פייק': ['albert pike'],
#              'אנדרה פרדש': ['andhra pradesh'],
#              'accelerated graphics port': ['accelerated graphics port',
#               'mrjacky/sandbox'],
#              'אלויס אלצהיימר': ['alois alzheimer'],
#              'איידיל': ['aedile'],
#              'אמריקן איירליינס': ['american airlines'],
#              'תרופות נוגדות דיכאון': ['antidepressant'],
#              "אפקט אוז'ה": ['auger effect'],
#              '11 באפריל': ['april 11'],
#              'דבק': ['adhesive'],
#              'אנתוני הופקינס': ['anthony hopkins'],
#              'amd': ['advanced micro devices'],
#              'אלברכט דירר': ['albrecht dürer'],
#              'פוטבול אוסטרלי': ['australian rules football'],
#              'אלבן ברג': ['alban berg'],
#              'כימיה אנליטית': ['analytical chemistry'],
#              'א-קפלה': ['a cappella'],
#              'עיבוד מוזיקלי': ['arrangement'],
#              'אליקנטה': ['alicante'],
#              '4 באוגוסט': ['august 4'],
#              'אורנגזב': ['aurangzeb'],
#              'חרוז אלכסנדרוני': ['alexandrine'],
#              'מחשב אנלוגי': ['analog computer'],
#              "אלברטו ג'קומטי": ['alberto giacometti'],
#              'המנון': ['anthem'],
#              'אלברכט אלטדורפר': ['albrecht altdorfer'],
#              'תאוצה': ['acceleration'],
#              'רסטורציה': ['conservation-restoration of cultural heritage',
#               'restoration'],
#              "אנטון צ'כוב": ['anton chekhov'],
#              'אפופטוזה': ['apoptosis'],
#              'מין אנאלי': ['anal sex'],
#              'אראו': ['aarau', 'fc aarau'],
#              'ארגאו': ['aargau'],
#              'אבא': ['aba'],
#              'אבדון': ['abaddon', 'oblivion'],
#              'שער הניצחון בפריז': ['arc de triomphe'],
#              '21 באפריל': ['april 21'],
#              'atm': ['atm'],
#              'אמאזוניט': ['amazonite'],
#              'אנתרופוסופיה': ['anthroposophy'],
#              'שור הבר': ['aurochs'],
#              'asynchronous transfer mode': ['asynchronous transfer mode'],
#              'פי הטבעת': ['anus'],
#              'הקונגרס הלאומי האפריקני': ['african national congress'],
#              'אמפטמין': ['amphetamine'],
#              'ארטילריה': ['artillery'],
#              'אלכסנדרפלאץ': ['alexanderplatz'],
#              'אסואן': ['aswan'],
#              'איירבוס a300': ['airbus a300'],
#              'אדנילט ציקלאז': ['adenylyl cyclase'],
#              'אלכסנדר קרנסקי': ['alexander kerensky'],
#              "אייג'נט אורנג'": ['agent orange'],
#              'ab urbe condita': ['ab urbe condita'],
#              'משפט מנהלי': ['administrative law'],
#              '10 באפריל': ['april 10'],
#              'אנדרה הענק': ['andré the giant'],
#              'אדרסטאה': ['adrastea'],
#              'apache http server': ['apache http server'],
#              'חשבונאות': ['accounting'],
#              'נמליים': ['ant'],
#              'השיטה האדברסרית': ['adversarial system'],
#              'אבא מרי הירחי': ['abba mari'],
#              'עבאס חלמי השני': ['abbas ii of egypt'],
#              'תוכנת פרסום': ['adware'],
#              'איאקוס': ['aeacus'],
#              'איידואים': ['aedui'],
#              'האיים האגאדיים': ['aegadian islands'],
#              'תרבויות אגאיות': ['aegean civilizations'],
#              'אגינה': ['aegina'],
#              'אייגיסתוס': ['aegisthus'],
#              'אייגוספוטמוי': ['aegospotami'],
#              'איליה קפיטולינה': ['aelia capitolina'],
#              'ספקטרוסקופיית בליעה אטומית': ['atomic absorption spectroscopy'],
#              "אז'אקסיו": ['ajaccio', 'ac ajaccio'],
#              'חיבה': ['affection'],
#              'רבי אבהו': ['abbahu'],
#              'עבד א-רחמן הראשון': ['abd al-rahman i'],
#              'עבד א-רחמן השלישי': ['abd-ar-rahman iii'],
#              'אבדילאזיז': ['abdülaziz of the ottoman empire'],
#              'אבדרה': ['thrace abdera'],
#              "מלך סקוטלנד אייד'": ['áed mac cináeda'],
#              'אבדילהמיט הראשון': ['abdul hamid i'],
#              'אברציה': ['aberration'],
#              'אברציה כוכבית': ['aberration of light'],
#              'אברציה אופטית': ['optical aberration'],
#              'איימי גרנט': ['amy grant'],
#              'אנדרס צלזיוס': ['anders celsius'],
#              '25 באפריל': ['april 25'],
#              '24 באפריל': ['april 24'],
#              '7 באפריל': ['april 7'],
#              'אנדלוסיה': ['andalusia'],
#              'אביתר': ['abiathar',
#               'eviatar',
#               'eviatar',
#               'eviatar',
#               'eviatar',
#               'evyatar'],
#              'אביגיל': ['abigail', 'avigayil'],
#              'אזאד קשמיר': ['azad kashmir'],
#              'הים הערבי': ['arabian sea'],
#              'אספרטם': ['aspartame'],
#              'אוטוקאד': ['autocad'],
#              'רבייה אל-זוויגית': ['asexual reproduction'],
#              'אלקן': ['alkene', 'elkan'],
#              'אלקין': ['alkyne', 'elkin'],
#              'abiword': ['abiword'],
#              'מבחן איימס': ['ames test'],
#              'מעכבי ace': ['ace inhibitor'],
#              'parallel ata': ['parallel ata'],
#              'אהימסה': ['ahimsa'],
#              'annals of mathematics': ['annals of mathematics'],
#              'אנדריי סחרוב': ['andrei sakharov'],
#              'אסטרוביולוגיה': ['astrobiology'],
#              'העיקרון האנתרופי': ['anthropic principle'],
#              'צבא אוסטרליה': ['australian army'],
#              'active directory': ['active directory'],
#              'אריאן': ['arian', 'ariane', 'ariane', 'arianne'],
#              "אהרון נימצוביץ'": ['aron nimzowitsch'],
#              'אראגונית': ['aragonese language'],
#              'אווירודינמיקה': ['aerodynamics'],
#              'אפר': ['ash', 'afar'],
#              'השושלת האנטיגונידית': ['antigonid dynasty'],
#              'כלב אפגני': ['afghan hound'],
#              'אזוואק': ['azawakh'],
#              'אקריליק': ['acrylic paint'],
#              'תנע זוויתי': ['angular momentum'],
#              'מודל עוגת הצימוקים': ['plum pudding model'],
#              'התורה האטומית': ['atomic theory'],
#              "אונג סן סו צ'י": ['aung san suu kyi'],
#              'אברהם יהושע השל': ['abraham joshua heschel'],
#              'ספר החיות של אברדין': ['aberdeen bestiary'],
#              'תצפיתנות כלי טיס': ['aircraft spotting'],
#              'פרסומת': ['advertising'],
#              'מד זרם': ['ammeter'],
#              'אמנדה הסר': ['amanda hesser'],
#              'תרופות אנטי-פסיכוטיות': ['antipsychotic'],
#              'דוכס טשן הארכידוכס קרל': ['duke of teschen archduke charles'],
#              'active server pages': ['active server pages'],
#              'אמוקסיצילין': ['amoxicillin'],
#              'אמורפיות': ['amorphous solid'],
#              'הקוסם מארץ ים': ['a wizard of earthsea'],
#              'אלכס לייפסן': ['alex lifeson'],
#              'ארטמיס': ['artemis'],
#              'העבודה משחררת': ['arbeit macht frei'],
#              'לבקנות': ['albinism'],
#              'אנאיס נין': ['anaïs nin'],
#              'פונקציית אקרמן': ['ackermann function'],
#              'acm': ['association for computing machinery'],
#              'אנבפטיזם': ['anabaptists'],
#              'ירושלים': ['and did those feet in ancient time',
#               'jerusalem',
#               'jerusalem',
#               'jerusalem',
#               'jérusalem'],
#              'אריאל שרון': ['ariel sharon'],
#              'אנואה': ['anoa'],
#              'אגנר קרארוף ארלנג': ['agner krarup erlang'],
#              'אלקלי': ['alkali'],
#              'אלכוהוליזם': ['alcoholism'],
#              'הפשטה': ['abstraction', 'abstraction'],
#              'חבורה אבלית': ['abelian group'],
#              'האימפריה האוסטרו-הונגרית': ['austria-hungary'],
#              'אברקדברה': ['abracadabra'],
#              'חוקי האיחוד של 1707': ['acts of union 1707'],
#              'האדמירליות': ['admiralty'],
#              'אמפיביה': ['amphibian'],
#              'קטיעה': ['amputation'],
#              'מד רוח': ['anemometer'],
#              'ארכאופטריקס': ['archaeopteryx'],
#              "אלן ג'יי לרנר": ['alan jay lerner'],
#              'אנלציט': ['analcime'],
#              "אלכסיי פז'יטנוב": ['alexey pajitnov'],
#              "עבד אל-בהאא'": ["`abdu'l-bahá"],
#              'אנוביס': ['anubis', 'anubis'],
#              'דבר מצחיק קרה לי בדרך לפורום': ['a funny thing happened on the way to the forum'],
#              'סתיו': ['autumn', 'stav', 'stav'],
#              'סליל אלפא': ['alpha helix'],
#              'ארמגדון': ['armageddon', 'armageddon', 'armageddon'],
#              'athlon': ['athlon'],
#              'אמנון': ['amnon',
#               'tilapia',
#               'tristramella sacra',
#               'amnun',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon',
#               'amnon'],
#              'אמו דריה': ['amu darya'],
#              'ארקטורוס': ['arcturus', 'arcturus'],
#              'אלברט ברוקס': ['albert brooks'],
#              'אנטארס': ['antares'],
#              'אלדברן': ['aldebaran'],
#              'אלטאיר': ['altair', 'altair'],
#              'אלכסנדריה': ['alexandria',
#               'alexandria',
#               'new south wales alexandria',
#               'virginia alexandria'],
#              'ממוצע אריתמטי-גאומטרי': ['arithmetic–geometric mean'],
#              'אליות': ['epsilon ursae majoris'],
#              'אסימפטוטה': ['asymptote'],
#              'אריאן 5': ['ariane 5'],
#              'אריתמטיקה': ['arithmetic', 'arithmetica'],
#              'סגור אלגברי': ['algebraic closure'],
#              'אדולף סאקס': ['adolphe sax'],
#              'מנושפות העיצורים': ['aspirated consonant'],
#              'אטלנטה': ['atlanta', 'atalanta b.c.'],
#              'בית בובות': ["a doll's house", 'dollhouse'],
#              'aim-7 ספארו': ['aim-7 sparrow'],
#              'aim-120 אמראם': ['aim-120 amraam'],
#              'agm-88 הארם': ['agm-88 harm'],
#              'agm-65 מאבריק': ['agm-65 maverick'],
#              'לוקהיד ac-130': ['lockheed ac-130'],
#              'אלגברה אלטרנטיבית': ['alternative algebra'],
#              "ארביטראז'": ['arbitrage'],
#              'פיורנטינה': ['acf fiorentina'],
#              'פונקציה אריתמטית': ['arithmetic function'],
#              'חוקי הזרים וההסתה': ['alien and sedition acts'],
#              'אנטינומיה': ['antinomy', "kant's antinomies"],
#              'תנאי שרשרת': ['ascending chain condition'],
#              'עדין אבן ישראל': ['adin steinsaltz'],
#              'אלפרד אדוארד האוסמן': ['a. housman'],
#              'אל קפונה': ['al capone'],
#              'אתנסיוס': ['athanasius of alexandria'],
#              'האיים האזוריים': ['azores'],
#              'בדיקות קבלה': ['acceptance testing'],
#              'ארנו': ['arno', 'arno atoll', 'arnault'],
#              'אנטוניוס הגדול': ['anthony the great'],
#              'נוסח השליחים': ["apostles' creed"],
#              'מספרים ידידים': ['amicable numbers'],
#              'אגר': ['agar', 'eger', 'agar', 'agger', 'eger', 'eggar'],
#              'גשם חומצי': ['acid rain'],
#              'מלך סקסוניה אנטון': ['anthony of saxony'],
#              "ארלו גאת'רי": ['arlo guthrie'],
#              'נוגד חמצון': ['antioxidant'],
#              'פליז': ['brass'],
#              'בון': ['bonn', 'bone', 'bone', 'bone', 'bone', 'boone', 'boone'],
#              'ריקודים סלוניים': ['ballroom dance'],
#              'הולדתה של אומה': ['the birth of a nation',
#               'the birth of a nation'],
#              'הים הבלטי': ['baltic sea'],
#              'מים מליחים': ['brackish water'],
#              'הברונקס': ['the bronx'],
#              'בלגיה': ['belgium'],
#              'בלוז': ['blues', 'bellows'],
#              'ברלין': ['berlin', 'berlin', 'berlin'],
#              'ביל קלינטון': ['bill clinton'],
#              'בירה': ['beer', 'beer'],
#              'סיבית': ['bit'],
#              'בית': ['byte',
#               'stanza',
#               'house',
#               'home',
#               'home',
#               'home',
#               'home'],
#              'בורון ניטריד': ['boron nitride'],
#              'באך': ['bach', 'bach', 'bach'],
#              'הבוורלי הילבילים': ['the beverly hillbillies'],
#              'בריליום': ['beryllium'],
#              'בריטני ספירס': ['britney spears'],
#              'ברזיל': ['brazil', 'brazil', 'brazil', 'caesalpinia echinata'],
#              'היער השחור': ['black forest'],
#              'הים השחור': ['black sea', 'black sea', 'black sea region'],
#              'ביבליה': ['bible'],
#              'קולומביה הבריטית': ['british columbia'],
#              'גאוטמה בודהה': ['gautama buddha'],
#              'גשר': ['bridge',
#               'bridge',
#               'bridge',
#               'bridging',
#               'israel gesher',
#               'gesher'],
#              'חריזה': ['beadwork', 'rhyme'],
#              'משחק לוח': ['board game'],
#              'חרוז': ['bead'],
#              'סרטנים מסננים': ['branchiopoda'],
#              'ברוך שפינוזה': ['baruch spinoza'],
#              'עופות': ['bird'],
#              '...baby one more time': ['...baby one more time',
#               '...baby one more time'],
#              'בולגריה': ['bulgaria', 'bulgaria'],
#              'חיטחבים': ['bryozoa'],
#              'בוטניקה - מונחים#צורות חיים של צמחים': ['biennial plant'],
#              'ביוויס ובאטהד': ['beavis and butt-head'],
#              'צלפאים': ['brassicales'],
#              'bbs': ['bulletin board system'],
#              'עיוורון': ['blindness'],
#              'הסימפוניה התשיעית של בטהובן': ['symphony no. 9'],
#              'מפציץ': ['bomber'],
#              'ביליארד': ['cue sports'],
#              'בורסה': ['bursa', 'share'],
#              'איי בהאמה': ['the bahamas'],
#              'בייקר': ['baker island',
#               'baker',
#               'baker',
#               'baker',
#               'baker',
#               'baker',
#               'baker',
#               'baker',
#               'baker',
#               'baker',
#               'baker',
#               'baker'],
#              'בנגלדש': ['bangladesh'],
#              'ברבדוס': ['barbados'],
#              'באסאס דה אינדיה': ['bassas da india'],
#              'בלארוס': ['belarus', 'belarus', 'a.h. king/sandbox2'],
#              'בליז': ['belize', 'belize'],
#              'בנין': ['benin', 'benin', 'banin'],
#              'ברמודה': ['bermuda'],
#              'בוליביה': ['bolivia'],
#              'בוסניה והרצגובינה': ['bosnia and herzegovina'],
#              'בוטסואנה': ['botswana'],
#              'ברוניי': ['brunei'],
#              'איי הבתולה הבריטיים': ['british virgin islands'],
#              'בורקינה פאסו': ['burkina faso'],
#              'ממשלת בלארוס': ['government of belarus'],
#              'דמוגרפיה של בוסניה והרצגובינה': ['demographics of bosnia and herzegovina'],
#              'פוליטיקה של בוסניה והרצגובינה': ['politics of bosnia and herzegovina'],
#              'גאוגרפיה של ברזיל': ['geography of brazil'],
#              'פוליטיקה של ברזיל': ['politics of brazil'],
#              'כלכלת ברזיל': ['economy of brazil'],
#              'הכוחות המזוינים של ברזיל': ['brazilian armed forces'],
#              'צבא בולגריה': ['bulgarian armed forces'],
#              'בוספורוס': ['bosphorus'],
#              'בריסל': ['brussels', 'city of brussels'],
#              'מעבדות נוקיה בל': ['nokia bell labs'],
#              'ביארן סטרוסטרופ': ['bjarne stroustrup'],
#              'מוח': ['brain', 'neurogeek/brain'],
#              'ביזנטיון': ['byzantium'],
#              'חומת ברלין': ['berlin wall'],
#              'קרב אדריאנופול': ['battle of adrianople',
#               'battle of adrianople',
#               'battle of adrianople'],
#              'באנגרה': ['bhangra'],
#              'ביסטי בויז': ['beastie boys'],
#              'האיים הבריטיים': ['british isles'],
#              'בסקית': ['basque language'],
#              'ביורן אולבאוס': ['björn ulvaeus'],
#              'בני אנדרסון': ['benny andersson'],
#              "בלוטות'": ['bluetooth'],
#              'בוני אם': ['boney m.'],
#              'בריטניה': ['britain', 'roman britain', 'britannia'],
#              'בלייד ראנר': ['blade runner'],
#              'ביל גייטס': ['bill gates'],
#              'בורבון': ['bourbon', 'bourbon whiskey'],
#              'בור': ['boron',
#               'bor',
#               'serbia bor',
#               'south sudan bor',
#               'boer',
#               'boer',
#               'boer',
#               'boer'],
#              'ברום': ['bromine', 'western australia broome', 'brom', 'brom'],
#              'בריום': ['barium'],
#              'ברקליום': ['berkelium'],
#              'בוקסיט': ['bauxite'],
#              'בוואריה': ['bavaria'],
#              'ברנדנבורג': ['brandenburg',
#               'brandenburg an der havel',
#               'brandenburg'],
#              'בונדסטאג': ['bundestag'],
#              'bmw': ['bmw'],
#              'דו-מיני': ['bisexual'],
#              'בורנהולם': ['bornholm'],
#              'ספר': ['book', 'frontier', 'barber', 'sefer'],
#              'בילה אוגוסט': ['bille august'],
#              'ביטולה': ['bitola'],
#              "קרב בוסוורת'": ['battle of bosworth field'],
#              'מצליבים': ['brassicaceae'],
#              'boogie down productions': ['boogie down productions'],
#              'עשרוני בקידוד בינארי': ['binary-coded decimal'],
#              'בינארי': ['binary'],
#              'באוהאוס': ['bauhaus', 'bauhaus', 'bauhaus'],
#              'ביאוולף': ['beowulf'],
#              'אוכפים לוהטים': ['blazing saddles'],
#              "בריז'יט בארדו": ['brigitte bardot'],
#              "בנג'ו": ['banjo', 'banjo'],
#              'בייסבול': ['baseball'],
#              'בייסבול - עמדות': ['baseball positions'],
#              'mvp של ה-mlb': ['major league baseball most valuable player award'],
#              'ברנרד לו מונטגומרי': ['bernard montgomery'],
#              "בנג'מין ד'יזראלי": ['benjamin disraeli'],
#              'התפלגות בינומית': ['binomial distribution'],
#              'ביומטריה': ['biostatistics'],
#              'גיטרה בס': ['bass guitar'],
#              'כדורסל': ['basketball'],
#              'כדור משחק': ['ball'],
#              'יחס': ['binary relation', 'ratio'],
#              'כתב ברייל': ['braille'],
#              'יום הבסטיליה': ['bastille day'],
#              'blowfish': ['blowfish'],
#              'פונקציה חד-חד-ערכית ועל': ['bijection'],
#              'קטיפה כחולה': ['blue velvet'],
#              'פעולה בינארית': ['binary operation'],
#              'חמת חלילים': ['bagpipes'],
#              'ביוכימיה': ['biochemistry', 'pifanatic/biochemistry'],
#              'בדמינטון': ['badminton'],
#              'בארוק': ['baroque'],
#              'אלגברה בוליאנית': ['boolean algebra', 'boolean algebra'],
#              "ביל ג'וי": ['bill joy'],
#              'רוחב סרט': ['bandwidth'],
#              'ארמון בקינגהאם': ['buckingham palace'],
#              'בריטיש איירווייז': ['british airways'],
#              'אופניים': ['bicycle'],
#              'ביופולימרים': ['biopolymer'],
#              'ספר מורמון': ['book of mormon'],
#              'בפטיזם': ['baptists'],
#              "בלאק ג'ק": ['blackjack'],
#              'ביקרבונט': ['bicarbonate'],
#              'באפלו': ['new york buffalo'],
#              "בנג'מין פרנקלין": ['benjamin franklin'],
#              'מרחב בנך': ['banach space'],
#              'ברם סטוקר': ['bram stoker'],
#              "ברידג'": ['contract bridge'],
#              'סירה': ['boat'],
#              'בנואה מנדלברוט': ['benoit mandelbrot'],
#              'בנדיקטוס מנורסיה': ['benedict of nursia'],
#              'קרב פרסלוס': ['battle of pharsalus'],
#              'ביגפוט': ['bigfoot'],
#              'בינג קרוסבי': ['bing crosby'],
#              'בסיס': ['base', 'basis', 'base', 'base', 'radix'],
#              'אמנת בזל': ['basel convention'],
#              'basic': ['basic'],
#              'קיסרי האימפריה הביזנטית': ['list of byzantine emperors'],
#              'אפקט הפרפר': ['butterfly effect', 'the butterfly effect'],
#              'בורלנד': ['borland', 'borland'],
#              'באקמינסטר פולר': ['buckminster fuller'],
#              'שחור': ['black', 'black', "sh'chur"],
#              "בלצ'לי פארק": ['bletchley park'],
#              'בדה ונרביליס': ['bede'],
#              'קרב בלנהיים': ['battle of blenheim'],
#              'קרב ראמיאי': ['battle of ramillies'],
#              'בריאן קרניגהאן': ['brian kernighan'],
#              'אוניית מערכה': ['battleship'],
#              'ביפרוסט': ['bifröst'],
#              'סיירת מערכה': ['battlecruiser'],
#              'בוב הוק': ['bob hawke'],
#              'בלדר': ['baldr', 'balder'],
#              ...})

# %%
import editdistance # !pip install editdistance

def get_distance(word,trans):
    """
    A function that takes word and predicted translation
    and evaluates (Levenshtein's) edit distance to closest correct translation
    """
    references = word_to_translation[word]
    assert len(references)!=0,"wrong/unknown word"
    return min(editdistance.eval(trans,ref) for ref in references)

def score(words, bsize=100):
    """a function that computes levenshtein distance for bsize random samples"""
    assert isinstance(words,np.ndarray)
    
    batch_words = np.random.choice(words,size=bsize,replace=False)
    batch_trans = translate(batch_words)
    
    distances = list(map(get_distance,batch_words,batch_trans))
    
    return np.array(distances,dtype='float32')

# %%
#should be around 5-50 and decrease rapidly after training :)
[score(test_words,10).mean() for _ in range(5)]
# Out:
# [48.9, 48.9, 48.6, 48.9, 49.0]

# %% [markdown]
# ## Step 2: Supervised pre-training (2 points)
#
# Here we define a function that trains our model through maximizing log-likelihood a.k.a. minimizing crossentropy.

# %%
import random
def sample_batch(words, word_to_translation, batch_size):
    """
    sample random batch of words and random correct translation for each word
    example usage:
    batch_x,batch_y = sample_batch(train_words, word_to_translations,10)
    """
    #choose words
    batch_words = np.random.choice(words,size=batch_size)
    
    #choose translations
    batch_trans_candidates = list(map(word_to_translation.get, batch_words))
    batch_trans = list(map(random.choice, batch_trans_candidates))
    return batch_words, batch_trans

# %%
bx,by = sample_batch(train_words, word_to_translation, batch_size=3)
print("Source:")
print(bx)
print("Target:")
print(by)
# Out:
# Source:
# ['אלוברוגים' 'אני בנמל מאדים בלי הילדה' 'סמנתה']
# Target:
# ['allobroges', "i'm in marsport without hilda", 'samantha']

# %%
from lstm_model_torch_cuda import infer_length, infer_mask, to_one_hot

def compute_loss_on_batch(input_sequence, reference_answers):
    """ Compute crossentropy loss given a batch of sources and translations """
    input_sequence = Variable(torch.LongTensor(inp_voc.to_matrix(input_sequence))).cuda()
    reference_answers = Variable(torch.LongTensor(out_voc.to_matrix(reference_answers))).cuda()
    
    # Compute log-probabilities of all possible tokens at each step. Use model interface.
    logprobs_seq = model(input_sequence, reference_answers)
    # compute elementwise crossentropy as negative log-probabilities of reference_answers.
    crossentropy = - torch.sum(logprobs_seq * to_one_hot(reference_answers, len(out_voc)), dim = -1)
    assert crossentropy.dim() == 2, "please return elementwise crossentropy, don't compute mean just yet"
    
    # average with mask
    mask = infer_mask(reference_answers, out_voc.eos_ix)
    loss = torch.sum(crossentropy * mask) / torch.sum(mask)

    return loss

# %%
#test it
loss = compute_loss_on_batch(*sample_batch(train_words, word_to_translation, 3))
print('loss = ', loss)

assert isinstance(loss, Variable) and tuple(loss.data.cpu().shape)==(1,)
loss.backward()
for w in model.parameters():
    assert w.grad is not None and torch.max(torch.abs(w.grad)).data.cpu().numpy()[0] != 0, \
        "Loss is not differentiable w.r.t. a weight with shape %s. Check comput_loss_on_batch." % (w.size(),)
# Out:
# loss =  Variable containing:
#  5.4358
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %% [markdown]
# ##### Actually train the model
#
# Minibatches and stuff...

# %%
from IPython.display import clear_output
from tqdm import tqdm, trange #or use tqdm_notebook,tnrange

loss_history = []
editdist_history = []
entropy_history = []
opt = torch.optim.Adam(model.parameters())

# %%
for i in trange(25000):
    loss = compute_loss_on_batch(*sample_batch(train_words,word_to_translation,32))
    
    #train with backprop
    loss.backward()
    opt.step()
    opt.zero_grad()
    
    loss_history.append(loss.data.cpu().numpy()[0])
    
    if (i+1)%REPORT_FREQ==0:
        clear_output(True)
        current_scores = score(test_words)
        editdist_history.append(current_scores.mean())
        plt.figure(figsize=(12,4))
        plt.subplot(131)
        plt.title('train loss / traning time')
        plt.plot(loss_history)
        plt.grid()
        plt.subplot(132)
        plt.title('val score distribution')
        plt.hist(current_scores, bins = 20)
        plt.subplot(133)
        plt.title('val score / traning time (lower is better)')
        plt.plot(editdist_history)
        plt.grid()
        plt.show()
        print("llh=%.3f, mean score=%.3f"%(np.mean(loss_history[-10:]),np.mean(editdist_history[-10:])))
# Out:
#  64%|██████▍   | 16001/25000 [2:16:11<2:43:22,  1.09s/it]
# llh=0.842, mean score=9.752
#  64%|██████▍   | 16055/25000 [2:16:35<35:37,  4.19it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-e1f6ac1f8445> in <module>()
#       1 for i in trange(25000):
# ----> 2     loss = compute_loss_on_batch(*sample_batch(train_words,word_to_translation,32))
#       3
#       4     #train with backprop
#       5     loss.backward()
#
# <ipython-input-42-c0fb26bfb752> in compute_loss_on_batch(input_sequence, reference_answers)
#       7
#       8     # Compute log-probabilities of all possible tokens at each step. Use model interface.
# ----> 9     logprobs_seq = model(input_sequence, reference_answers)
#      10     # compute elementwise crossentropy as negative log-probabilities of reference_answers.
#      11     crossentropy = - torch.sum(logprobs_seq * to_one_hot(reference_answers, len(out_voc)), dim = -1)
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /home/shirobokov/Practical_RL/week8_scst/lstm_model_torch_cuda.py in forward(self, inp, out, eps, **flags)
#      96         logits_seq = [torch.log(to_one_hot(bos, len(self.out_voc)) + eps)]
#      97
# ---> 98         hid_state = self.encode(inp, **flags)
#      99         for x_t in out.transpose(0,1)[:-1]:
#     100             hid_state, logits = self.decode(hid_state, x_t, **flags)
#
# /home/shirobokov/Practical_RL/week8_scst/lstm_model_torch_cuda.py in encode(self, inp, **flags)
#      40         inp_emb = self.emb_inp(inp)
#      41
# ---> 42         enc_seq_lower, _ = self.enc_bi_LSTM(inp_emb)
#      43
#      44         enc_seq_upper, _ = self.enc_LSTM(enc_seq_lower)
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     202             flat_weight=flat_weight
#     203         )
# --> 204         output, hidden = func(input, self.all_weights, hx)
#     205         if is_packed:
#     206             output = PackedSequence(output, batch_sizes)
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, *fargs, **fkwargs)
#     383             return hack_onnx_rnn((input,) + fargs, output, args, kwargs)
#     384         else:
# --> 385             return func(input, *fargs, **fkwargs)
#     386
#     387     return forward
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/autograd/function.py in _do_forward(self, *input)
#     326         self._nested_input = input
#     327         flat_input = tuple(_iter_variables(input))
# --> 328         flat_output = super(NestedIOFunction, self)._do_forward(*flat_input)
#     329         nested_output = self._nested_output
#     330         nested_variables = _unflatten(flat_output, self._nested_output)
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/autograd/function.py in forward(self, *args)
#     348     def forward(self, *args):
#     349         nested_tensors = _map_variable_tensor(self._nested_input)
# --> 350         result = self.forward_extended(*nested_tensors)
#     351         del self._nested_input
#     352         self._nested_output = result
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward_extended(self, input, weight, hx)
#     292             hy = tuple(h.new() for h in hx)
#     293
# --> 294         cudnn.rnn.forward(self, input, hx, weight, output, hy)
#     295
#     296         self.save_for_backward(input, hx, weight, output)
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/backends/cudnn/rnn.py in forward(fn, input, hx, weight, output, hy)
#     226
#     227         # init descriptors
# --> 228         fn.rnn_desc = init_rnn_descriptor(fn, handle)
#     229         if is_input_packed:
#     230             fn.x_descs = cudnn.descriptor_sequence(x, fn.batch_sizes)
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/backends/cudnn/rnn.py in init_rnn_descriptor(fn, handle)
#      52         fn.bidirectional,
#      53         fn.mode,
# ---> 54         fn.datatype
#      55     )
#      56
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/backends/cudnn/__init__.py in __init__(self, handle, hidden_size, num_layers, dropout_desc, input_mode, bidirectional, mode, datatype)
#     259             ))
#     260             if version() >= 7000 and int(cuda[0]) >= 9 and (
# --> 261                     torch.cuda.get_device_capability(torch.cuda.current_device())[0] >= 7):
#     262                 lib.cudnnSetRNNMatrixMathType(self, CUDNN_DEFAULT_MATH)
#     263                 if datatype == CUDNN_DATA_HALF:
#
# /home/shirobokov/.local/lib/python3.6/site-packages/torch/cuda/__init__.py in get_device_capability(device)
#     266     """
#     267     if device >= 0:
# --> 268         return torch._C._cuda_getDeviceCapability(device)
#     269
#     270
#
# KeyboardInterrupt:

# %%
# params_to_dict = dict(map(lambda x: (x, params[x].cpu()), params))

# %%
# with open("supervised_Full_model_cuda.pt", 'wb') as f:
#     torch.save(model, f)

# %% [markdown]
# __How to interpret the plots:__
#
# * __Train loss__ - that's your model's crossentropy over minibatches. It should go down steadily. Most importantly, it shouldn't be NaN :)
# * __Val score distribution__ - distribution of translation edit distance (score) within batch. It should move to the left over time.
# * __Val score / training time__ - it's your current mean edit distance. This plot is much whimsier than loss, but make sure it goes below 8 by 2500 steps.
#
# If it doesn't, first try to re-create both model and opt. You may have changed it's weight too much while debugging. If that doesn't help, it's debugging time.

# %%
for word in train_words[:10]:
    print("%s -> %s"%(word,translate([word])[0]))
# Out:
# שריר הטרפז -> transform security sound
# סוורן סוזוקי -> sever sunzowic
# ח'ארג -> kharag
# מוזיקה מנוונת -> connection of monastery
# אריסימון -> arismanon
# java -> java
# לטימריה -> letimira
# אנווטאק -> anwatak
# ג'יימי לי קרטיס -> jame lie crites
# קטגוריה:ילדי נשיאי ארצות הברית -> presidents of the united states army

# %%
test_scores = []
for start_i in trange(0,len(test_words),32):
    batch_words = test_words[start_i:start_i+32]
    batch_trans = translate(batch_words)
    distances = list(map(get_distance,batch_words,batch_trans))
    test_scores.extend(distances)
    
print("Supervised test score:",np.mean(test_scores))
# Out:
#   0%|          | 0/569 [00:00<?, ?it/s]
# 100%|██████████| 569/569 [02:42<00:00,  3.50it/s]
# Supervised test score: 9.607997359881194

# %% [markdown]
# ## Self-critical policy gradient (2 points)
#
# In this section you'll implement algorithm called self-critical sequence training (here's an [article](https://arxiv.org/abs/1612.00563)).
#
# The algorithm is a vanilla policy gradient with a special baseline.
#
# $$ \nabla J = E_{x \sim p(s)} E_{y \sim \pi(y|x)} \nabla log \pi(y|x) \cdot (R(x,y) - b(x)) $$
#
# Here reward R(x,y) is a __negative levenshtein distance__ (since we minimize it). The baseline __b(x)__ represents how well model fares on word __x__.
#
# In practice, this means that we compute baseline as a score of greedy translation, $b(x) = R(x,y_{greedy}(x)) $.
#
# Luckily, we already obtained the required outputs: `model.greedy_translations, model.greedy_mask` and we only need to compute levenshtein using `compute_levenshtein` function.

# %%
def compute_reward(input_sequence, translations):
    """ computes sample-wise reward given token ids for inputs and translations """
    distances = list(map(get_distance, 
                         inp_voc.to_lines(input_sequence.data.cpu().numpy()), 
                         out_voc.to_lines(translations.data.cpu().numpy())))
    # use negative levenshtein distance so that larger reward means better policy
    return - Variable(torch.FloatTensor(distances)).cuda()

# %%
def scst_objective_on_batch(input_sequence, max_len=MAX_OUTPUT_LENGTH):
    """ Compute pseudo-loss for policy gradient given a batch of sources """
    input_sequence = Variable(torch.LongTensor(inp_voc.to_matrix(input_sequence))).cuda()
    
    # use model to __sample__ symbolic translations given input_sequence
    sample_translations, sample_logp = model.translate(input_sequence, greedy=False, max_len=max_len)
    # use model to __greedy__ symbolic translations given input_sequence
    greedy_translations, greedy_logp = model.translate(input_sequence, greedy=True, max_len=max_len)
    
    #compute rewards and advantage
    rewards = compute_reward(input_sequence, sample_translations)
    baseline = compute_reward(input_sequence, greedy_translations)

    # compute advantage using rewards and baseline
    advantage = rewards - baseline

    # compute log_pi(a_t|s_t), shape = [batch, seq_length]
    logp_sample = torch.sum(sample_logp * to_one_hot(sample_translations, len(out_voc)), dim=-1)
    
    # policy gradient pseudo-loss. Gradient of J is exactly policy gradient.
    J = logp_sample * advantage[:,None]

    assert J.dim() == 2, "please return elementwise objective, don't compute mean just yet"
    
    # average with mask
    mask = infer_mask(sample_translations, out_voc.eos_ix)
    loss = - torch.sum(J * mask) / torch.sum(mask)
    
    # regularize with negative entropy. Don't forget the sign!
    # note: for entropy you need probabilities for all tokens (sample_logp), not just logp_sample
    # <compute entropy matrix of shape [batch,seq_length], H=-sum(p*log_p), don't forget the sign!>    
    entropy = - (sample_logp * torch.exp(sample_logp)).sum(dim=-1)

    assert entropy.dim() == 2, "please make sure elementwise entropy is of shape [batch,time]"

    reg = - 0.01 * torch.sum(entropy * mask) / torch.sum(mask)

    return loss + reg, torch.sum(entropy * mask) / torch.sum(mask)

# %% [markdown]
# # Policy gradient training

# %%
entropy_history = [np.nan] * len(loss_history)
opt = torch.optim.Adam(model.parameters(), lr=1e-5)

# %%
for i in trange(100000):
    loss, ent = scst_objective_on_batch(sample_batch(train_words,word_to_translation,32)[0])
    
    #train with backprop
    loss.backward()
    opt.step()
    opt.zero_grad()

    
    loss_history.append(loss.data.cpu().numpy()[0])
    entropy_history.append(ent.data.cpu().numpy()[0])
    
    if (i+1)%REPORT_FREQ==0:
        clear_output(True)
        current_scores = score(test_words)
        editdist_history.append(current_scores.mean())
        plt.figure(figsize=(12,4))
        plt.subplot(131)
        plt.title('val score distribution')
        plt.hist(current_scores, bins = 20)
        plt.subplot(132)
        plt.title('val score / traning time')
        plt.plot(editdist_history)
        plt.grid()
        plt.subplot(133)
        plt.title('policy entropy / traning time')
        plt.plot(entropy_history)
        plt.grid()
        plt.show()
        print("J=%.3f, mean score=%.3f"%(np.mean(loss_history[-10:]),np.mean(editdist_history[-10:])))
# Out:
# 100%|██████████| 100000/100000 [19:14:07<00:00,  1.53it/s]
# J=-0.514, mean score=7.289

# %% [markdown]
# __Debugging tips:__
# <img src=https://s14.postimg.org/4cb3lmm1t/do_something_scst.png width=400>
#
#  * As usual, don't expect improvements right away, but in general the model should be able to show some positive changes by 5k steps.
#  * Entropy is a good indicator of many problems.
#    * If it reaches zero, you may need greater entropy regularizer.
#    * If it has rapid changes time to time, you may need gradient clipping.
#    * If it oscillates up and down in an erratic manner... it's perfectly okay for entropy to do so. But it should decrease at the end.
#
#  * We don't show loss_history cuz it's uninformative for pseudo-losses in policy gradient. However, if something goes wrong you can check it to see if everything isn't a constant zero.

# %% [markdown]
# ### Results

# %%
for word in train_words[:10]:
    print("%s -> %s"%(word,translate([word])[0]))
# Out:
# שריר הטרפז -> transfer serie
# סוורן סוזוקי -> severn sokosi
# ח'ארג -> kharg
# מוזיקה מנוונת -> mane music
# אריסימון -> arisimon
# java -> java
# לטימריה -> latimira
# אנווטאק -> anwatak
# ג'יימי לי קרטיס -> jame li clites
# קטגוריה:ילדי נשיאי ארצות הברית -> people counties of the united states

# %%
test_scores = []
for start_i in trange(0,len(test_words),32):
    batch_words = test_words[start_i:start_i+32]
    batch_trans = translate(batch_words)
    distances = list(map(get_distance,batch_words,batch_trans))
    test_scores.extend(distances)
print("Supervised test score:",np.mean(test_scores))

# ^^ If you get Out Of MemoryError, please replace this with batched computation
# Out:
# 100%|██████████| 569/569 [02:21<00:00,  4.03it/s]
# Supervised test score: 7.761069248116165

# %% [markdown]
# ## Step 6: Make it actually work (5++ pts)
#
# In this section we want you to finally __restart with EASY_MODE=False__ and experiment to find a good model/curriculum for that task.
#
# We recommend you to start with the following architecture
#
# ```
# encoder---decoder
#
#            P(y|h)
#              ^
#  LSTM  ->   LSTM
#   ^          ^
#  biLSTM  ->   LSTM
#   ^          ^
# input       y_prev
# ```
#
# __Note:__ you can fit all 4 state tensors of both LSTMs into a in a single state - just assume that it contains, for example, [h0, c0, h1, c1] - pack it in encode and update in decode.
#
#
# Here are some cool ideas on what you can do then.
#
# __General tips & tricks:__
# * In some tensorflow versions and for some layers, it is required that each rnn/gru/lstm cell gets it's own `tf.variable_scope(unique_name, reuse=False)`.
#   * Otherwise it will complain about wrong tensor sizes because it tries to reuse weights from one rnn to the other.
# * You will likely need to adjust pre-training time for such a network.
# * Supervised pre-training may benefit from clipping gradients somehow.
# * SCST may indulge a higher learning rate in some cases and changing entropy regularizer over time.
# * It's often useful to save pre-trained model parameters to not re-train it every time you want new policy gradient parameters.
# * When leaving training for nighttime, try setting REPORT_FREQ to a larger value (e.g. 500) not to waste time on it.
#
# __Formal criteria:__
# To get 5 points we want you to build an architecture that:
# * _doesn't consist of single GRU_
# * _works better_ than single GRU baseline.
# * We also want you to provide either learning curve or trained model, preferably both
# * ... and write a brief report or experiment log describing what you did and how it fared.
#
# ### Attention
# There's more than one way to connect decoder to encoder
#   * __Vanilla:__ layer_i of encoder last state goes to layer_i of decoder initial state
#   * __Every tick:__ feed encoder last state _on every iteration_ of decoder.
#   * __Attention:__ allow decoder to "peek" at one (or several) positions of encoded sequence on every tick.
#
# The most effective (and cool) of those is, of course, attention.
# You can read more about attention [in this nice blog post](https://distill.pub/2016/augmented-rnns/). The easiest way to begin is to use "soft" attention with "additive" or "dot-product" intermediate layers.
#
# __Tips__
# * Model usually generalizes better if you no longer allow decoder to see final encoder state
# * Once your model made it through several epochs, it is a good idea to visualize attention maps to understand what your model has actually learned
#
# * There's more stuff [here](https://github.com/yandexdataschool/Practical_RL/blob/master/week8_scst/bonus.ipynb)
# * If you opted for hard attention, we recommend [gumbel-softmax](https://blog.evjang.com/2016/11/tutorial-categorical-variational.html) instead of sampling. Also please make sure soft attention works fine before you switch to hard.
#
# ### UREX
# * This is a way to improve exploration in policy-based settings. The main idea is that you find and upweight under-appreciated actions.
# * Here's [video](https://www.youtube.com/watch?v=fZNyHoXgV7M&feature=youtu.be&t=3444)
#  and an [article](https://arxiv.org/abs/1611.09321).
# * You may want to reduce batch size 'cuz UREX requires you to sample multiple times per source sentence.
# * Once you got it working, try using experience replay with importance sampling instead of (in addition to) basic UREX.
#
# ### Some additional ideas:
# * (advanced deep learning) It may be a good idea to first train on small phrases and then adapt to larger ones (a.k.a. training curriculum).
# * (advanced nlp) You may want to switch from raw utf8 to something like unicode or even syllables to make task easier.
# * (advanced nlp) Since hebrew words are written __with vowels omitted__, you may want to use a small Hebrew vowel markup dataset at `he-pron-wiktionary.txt`.

# %%
assert not EASY_MODE, "make sure you set EASY_MODE = False at the top of the notebook."

# %% [markdown]
# `[your report/log here or anywhere you please]`

# %% [markdown]
# __Contributions:__ This notebook is brought to you by
# * Yandex [MT team](https://tech.yandex.com/translate/)
# * Denis Mazur ([DeniskaMazur](https://github.com/DeniskaMazur)), Oleg Vasilev ([Omrigan](https://github.com/Omrigan/)), Dmitry Emelyanenko ([TixFeniks](https://github.com/tixfeniks)) and Fedor Ratnikov ([justheuristic](https://github.com/justheuristic/))
# * Dataset is parsed from [Wiktionary](https://en.wiktionary.org), which is under CC-BY-SA and GFDL licenses.
